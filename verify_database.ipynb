# %%
import sqlite3
import pandas as pd

# %%
conn = sqlite3.connect("data/customers.db")

df = pd.read_sql_query("SELECT * FROM customers", conn)

df
# Out:
#        customer_id     name                             email  \
# 0                1    Jared     gabriellehartman@benjamin.com
# 1                2    Marie              kstafford@sexton.com
# 2                3   Elijah           jeanettecross@brown.com
# 3                4   Sheryl          thomassierra@barrett.com
# 4                5   Jeremy  rubenwatkins@jacobs-wallace.info
# ...            ...      ...                               ...
# 17322        99819     Kirk              natalie85@harris.com
# 17323        99933     Joan        pinedaphyllis@barnett.info
# 17324        99971  Jeffrey               gperez@calderon.com
# 17325        99974   Jeanne          theresa61@frost-good.org
# 17326        99977   Joanna       codybishop@gould-flores.com
#
#                                             country
# 0                                           Eritrea
# 1                                          Botswana
# 2                                          Barbados
# ...
